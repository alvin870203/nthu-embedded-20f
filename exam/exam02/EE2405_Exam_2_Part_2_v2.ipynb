# %% [markdown]
# <a href="https://colab.research.google.com/github/AlvinChuang/exam02/blob/master/EE2405_Exam_2_Part_2_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EE2405 Embedded System Lab Exam #2 Part 2
#
# **Please click on "Open in playground" at the upper-left corner to create a copy for you.**
#
# ---
#
# **Please fill in correct statements in the right of the codes to finish the scripts.**
# Data sample is generated with a quadratic function and we will train a regression model to fit the data.
# And we convert and interpret the trained model with a Tensorflow lite APIs.
#
# You can run the script again after you fill all the blank to check the outputs.
#
# ---
#
# The Method to Download the Jupyter Notebook:
# File > Download .ipynb

# %% [markdown]
# ## Import dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf
# Numpy is a math library
import numpy as np
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# math is Python's math library
import math

# %% [markdown]
# ## Generate Data

# %%
# We'll generate this many sample datapoints
############################################################
#@markdown Please fill in the number of samples (the sample should be large enough, but not too large for computation).
SAMPLES = 800 #@param {type:"number"}
############################################################


############################################################
#@markdown Please fill in your student id, which is the random seed.
student_id = 105033110 #@param {type:"number"}
np.random.seed(student_id)
############################################################

# Generate a uniformly distributed set of random numbers
# in the range from 0 to 10
x_values = np.random.uniform(low=0, high=10, size=SAMPLES)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

############################################################
#@markdown Please fill in the statement to generate `y_values` with a quadratic function `y = x^2-5x+1`?
script = "y_values = pow(x_values,2)-5*x_values+1" #@param {type:"string"}
exec(script)
############################################################

# Plot our data.
# The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Add some noise

# %%
# Add a small random number to each y value
y_values += np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Split our data

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Design a model

# %%
# We'll use Keras to create a simple model architecture
from tensorflow.keras import layers
model = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model.add(layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second layer may help the network learn more complex representations
model.add(layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model.add(layers.Dense(1))

# Compile the model using a standard optimizer and loss function for regression
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ## Train the model

# %%
# Train the model on our training data while validating on our validation set
model.fit(x_train, y_train, epochs=1000, batch_size=16,
          validation_data=(x_validate, y_validate))

print("Done!")
# Out:
# Epoch 1/1000
# 30/30 [==============================] - 0s 4ms/step - loss: 266.8071 - mae: 11.1478 - val_loss: 146.8560 - val_mae: 8.6731
# Epoch 2/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 211.5841 - mae: 10.4286 - val_loss: 120.3620 - val_mae: 8.3057
# Epoch 3/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 172.2431 - mae: 9.9809 - val_loss: 105.5794 - val_mae: 8.3490
# Epoch 4/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 143.9678 - mae: 9.6903 - val_loss: 101.2589 - val_mae: 8.6449
# Epoch 5/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 129.7547 - mae: 9.5851 - val_loss: 102.9386 - val_mae: 8.9572
# Epoch 6/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 122.7217 - mae: 9.5448 - val_loss: 105.6808 - val_mae: 9.2024
# Epoch 7/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 119.4355 - mae: 9.5451 - val_loss: 104.4609 - val_mae: 9.1609
# Epoch 8/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 117.4085 - mae: 9.4297 - val_loss: 104.5399 - val_mae: 9.1902
# Epoch 9/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 115.0781 - mae: 9.3858 - val_loss: 102.2020 - val_mae: 9.0741
# Epoch 10/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 112.9233 - mae: 9.2460 - val_loss: 102.1527 - val_mae: 9.0893
# Epoch 11/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 111.0777 - mae: 9.1702 - val_loss: 100.2074 - val_mae: 8.9939
# Epoch 12/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 108.8144 - mae: 9.1005 - val_loss: 97.9412 - val_mae: 8.8799
# Epoch 13/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 105.9474 - mae: 8.9768 - val_loss: 92.1523 - val_mae: 8.5441
# Epoch 14/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 105.0406 - mae: 8.8367 - val_loss: 92.5460 - val_mae: 8.5995
# Epoch 15/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 102.6277 - mae: 8.7418 - val_loss: 93.0378 - val_mae: 8.6467
# Epoch 16/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 100.3655 - mae: 8.7006 - val_loss: 89.0896 - val_mae: 8.4339
# Epoch 17/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 98.0694 - mae: 8.5848 - val_loss: 86.5622 - val_mae: 8.3003
# Epoch 18/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 95.9253 - mae: 8.4305 - val_loss: 85.9598 - val_mae: 8.2866
# Epoch 19/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 93.4789 - mae: 8.3016 - val_loss: 85.5064 - val_mae: 8.2750
# Epoch 20/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 91.1982 - mae: 8.2353 - val_loss: 82.6054 - val_mae: 8.1219
# Epoch 21/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 88.8368 - mae: 8.1072 - val_loss: 79.9883 - val_mae: 7.9815
# Epoch 22/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 86.5962 - mae: 7.9841 - val_loss: 77.7914 - val_mae: 7.8657
# Epoch 23/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 84.1415 - mae: 7.8464 - val_loss: 77.0560 - val_mae: 7.8356
# Epoch 24/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 81.8848 - mae: 7.7554 - val_loss: 73.7980 - val_mae: 7.6550
# Epoch 25/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 79.7289 - mae: 7.6282 - val_loss: 72.4182 - val_mae: 7.5833
# Epoch 26/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 76.9818 - mae: 7.5246 - val_loss: 68.8533 - val_mae: 7.3813
# Epoch 27/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 74.5373 - mae: 7.3870 - val_loss: 66.4621 - val_mae: 7.2470
# Epoch 28/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 72.1769 - mae: 7.2452 - val_loss: 64.7110 - val_mae: 7.1506
# Epoch 29/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 69.5930 - mae: 7.1205 - val_loss: 62.2051 - val_mae: 7.0061
# Epoch 30/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 66.9281 - mae: 6.9821 - val_loss: 60.7247 - val_mae: 6.9262
# Epoch 31/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 64.3507 - mae: 6.8480 - val_loss: 57.1311 - val_mae: 6.7070
# Epoch 32/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 61.9164 - mae: 6.6673 - val_loss: 56.7031 - val_mae: 6.6878
# Epoch 33/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 59.5463 - mae: 6.5590 - val_loss: 54.7229 - val_mae: 6.5668
# Epoch 34/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 57.0118 - mae: 6.4105 - val_loss: 50.9122 - val_mae: 6.3306
# Epoch 35/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 54.7011 - mae: 6.2802 - val_loss: 50.0964 - val_mae: 6.2774
# Epoch 36/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 52.2773 - mae: 6.1580 - val_loss: 46.8291 - val_mae: 6.0686
# Epoch 37/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 49.7897 - mae: 5.9833 - val_loss: 44.2265 - val_mae: 5.8949
# Epoch 38/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 47.3049 - mae: 5.8254 - val_loss: 42.6981 - val_mae: 5.7862
# Epoch 39/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 44.8306 - mae: 5.6800 - val_loss: 39.5349 - val_mae: 5.5690
# Epoch 40/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 42.4963 - mae: 5.5374 - val_loss: 36.9252 - val_mae: 5.3810
# Epoch 41/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 40.0755 - mae: 5.3231 - val_loss: 37.6653 - val_mae: 5.4220
# Epoch 42/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 38.0771 - mae: 5.2296 - val_loss: 34.9738 - val_mae: 5.2240
# Epoch 43/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 35.7640 - mae: 5.0807 - val_loss: 29.8114 - val_mae: 4.8258
# Epoch 44/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 33.7634 - mae: 4.9112 - val_loss: 28.4986 - val_mae: 4.7134
# Epoch 45/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 31.6552 - mae: 4.7636 - val_loss: 27.0154 - val_mae: 4.5862
# Epoch 46/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 29.5472 - mae: 4.6033 - val_loss: 25.3779 - val_mae: 4.4405
# Epoch 47/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 27.6645 - mae: 4.4495 - val_loss: 23.2005 - val_mae: 4.2413
# Epoch 48/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 25.4011 - mae: 4.2707 - val_loss: 20.1175 - val_mae: 3.9394
# Epoch 49/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 23.2786 - mae: 4.0600 - val_loss: 18.2546 - val_mae: 3.7445
# Epoch 50/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 21.3112 - mae: 3.8914 - val_loss: 17.0873 - val_mae: 3.6192
# Epoch 51/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 19.3353 - mae: 3.6621 - val_loss: 17.9888 - val_mae: 3.7323
# Epoch 52/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 17.8536 - mae: 3.5665 - val_loss: 14.4692 - val_mae: 3.3193
# Epoch 53/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 16.3589 - mae: 3.3987 - val_loss: 13.2496 - val_mae: 3.1667
# Epoch 54/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 15.0296 - mae: 3.2147 - val_loss: 12.6159 - val_mae: 3.0862
# Epoch 55/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 13.7369 - mae: 3.0866 - val_loss: 10.9970 - val_mae: 2.8536
# Epoch 56/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 12.3105 - mae: 2.8823 - val_loss: 11.1880 - val_mae: 2.8872
# Epoch 57/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 11.1471 - mae: 2.7535 - val_loss: 8.8766 - val_mae: 2.5292
# Epoch 58/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 10.0683 - mae: 2.5763 - val_loss: 8.3911 - val_mae: 2.4625
# Epoch 59/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 9.2060 - mae: 2.4525 - val_loss: 7.4181 - val_mae: 2.2950
# Epoch 60/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 8.3886 - mae: 2.3323 - val_loss: 6.2661 - val_mae: 2.0700
# Epoch 61/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 7.7273 - mae: 2.2235 - val_loss: 6.3200 - val_mae: 2.1058
# Epoch 62/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 6.9357 - mae: 2.1142 - val_loss: 5.1871 - val_mae: 1.8633
# Epoch 63/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 6.5182 - mae: 2.0164 - val_loss: 5.4587 - val_mae: 1.9517
# Epoch 64/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 6.0169 - mae: 1.9516 - val_loss: 5.0289 - val_mae: 1.8668
# Epoch 65/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 5.6409 - mae: 1.9009 - val_loss: 4.3333 - val_mae: 1.7073
# Epoch 66/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 5.1713 - mae: 1.8075 - val_loss: 4.8862 - val_mae: 1.8460
# Epoch 67/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 4.8662 - mae: 1.7477 - val_loss: 3.9716 - val_mae: 1.6419
# Epoch 68/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 4.6906 - mae: 1.7312 - val_loss: 3.4907 - val_mae: 1.5022
# Epoch 69/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 4.4598 - mae: 1.6984 - val_loss: 3.3074 - val_mae: 1.4483
# Epoch 70/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 4.2167 - mae: 1.6319 - val_loss: 4.0416 - val_mae: 1.6609
# Epoch 71/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 4.0474 - mae: 1.6066 - val_loss: 3.1600 - val_mae: 1.4305
# Epoch 72/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 3.8835 - mae: 1.5696 - val_loss: 3.0199 - val_mae: 1.3883
# Epoch 73/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 3.7434 - mae: 1.5315 - val_loss: 2.9022 - val_mae: 1.3466
# Epoch 74/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 3.5156 - mae: 1.4831 - val_loss: 2.8406 - val_mae: 1.3305
# Epoch 75/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 3.3515 - mae: 1.4420 - val_loss: 2.7849 - val_mae: 1.3119
# Epoch 76/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 3.2586 - mae: 1.4177 - val_loss: 2.7467 - val_mae: 1.2989
# Epoch 77/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 3.0842 - mae: 1.3743 - val_loss: 2.5847 - val_mae: 1.2329
# Epoch 78/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 3.0423 - mae: 1.3663 - val_loss: 2.6233 - val_mae: 1.2529
# Epoch 79/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.8519 - mae: 1.3317 - val_loss: 2.4715 - val_mae: 1.1840
# Epoch 80/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.8438 - mae: 1.3124 - val_loss: 2.4458 - val_mae: 1.1878
# Epoch 81/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7393 - mae: 1.2850 - val_loss: 2.5307 - val_mae: 1.2172
# Epoch 82/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.7277 - mae: 1.2770 - val_loss: 2.4897 - val_mae: 1.2035
# Epoch 83/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.7033 - mae: 1.2573 - val_loss: 2.4084 - val_mae: 1.1750
# Epoch 84/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.6237 - mae: 1.2560 - val_loss: 2.3901 - val_mae: 1.1672
# Epoch 85/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.5551 - mae: 1.2254 - val_loss: 2.3470 - val_mae: 1.1533
# Epoch 86/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.5109 - mae: 1.2142 - val_loss: 2.3636 - val_mae: 1.1586
# Epoch 87/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4940 - mae: 1.2157 - val_loss: 2.3294 - val_mae: 1.1393
# Epoch 88/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4661 - mae: 1.2047 - val_loss: 2.7404 - val_mae: 1.2742
# Epoch 89/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.4107 - mae: 1.2020 - val_loss: 2.3500 - val_mae: 1.1551
# Epoch 90/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3882 - mae: 1.1694 - val_loss: 2.5115 - val_mae: 1.2055
# Epoch 91/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3676 - mae: 1.1738 - val_loss: 2.7347 - val_mae: 1.2746
# Epoch 92/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3585 - mae: 1.1711 - val_loss: 2.3071 - val_mae: 1.1362
# Epoch 93/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3645 - mae: 1.1742 - val_loss: 2.2916 - val_mae: 1.1281
# Epoch 94/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.3119 - mae: 1.1478 - val_loss: 2.4507 - val_mae: 1.1850
# Epoch 95/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2887 - mae: 1.1396 - val_loss: 2.2630 - val_mae: 1.1109
# Epoch 96/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2970 - mae: 1.1515 - val_loss: 2.4896 - val_mae: 1.2014
# Epoch 97/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2689 - mae: 1.1421 - val_loss: 2.3493 - val_mae: 1.1543
# Epoch 98/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2318 - mae: 1.1308 - val_loss: 2.2534 - val_mae: 1.1120
# Epoch 99/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2782 - mae: 1.1406 - val_loss: 2.4174 - val_mae: 1.1804
# Epoch 100/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2354 - mae: 1.1345 - val_loss: 2.2426 - val_mae: 1.0991
# Epoch 101/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2562 - mae: 1.1285 - val_loss: 2.2295 - val_mae: 1.1004
# Epoch 102/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2191 - mae: 1.1321 - val_loss: 2.3050 - val_mae: 1.1397
# Epoch 103/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2059 - mae: 1.1169 - val_loss: 2.2287 - val_mae: 1.1025
# Epoch 104/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1943 - mae: 1.1237 - val_loss: 2.5490 - val_mae: 1.2250
# Epoch 105/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1584 - mae: 1.1175 - val_loss: 2.2783 - val_mae: 1.1080
# Epoch 106/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1777 - mae: 1.1157 - val_loss: 2.5781 - val_mae: 1.2367
# Epoch 107/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.2125 - mae: 1.1247 - val_loss: 2.2279 - val_mae: 1.1042
# Epoch 108/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1857 - mae: 1.1122 - val_loss: 2.2338 - val_mae: 1.1085
# Epoch 109/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1891 - mae: 1.1150 - val_loss: 2.2095 - val_mae: 1.0904
# Epoch 110/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1847 - mae: 1.1114 - val_loss: 2.2275 - val_mae: 1.1068
# Epoch 111/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1527 - mae: 1.0956 - val_loss: 2.2117 - val_mae: 1.0963
# Epoch 112/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1965 - mae: 1.1224 - val_loss: 2.2202 - val_mae: 1.0946
# Epoch 113/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1484 - mae: 1.0988 - val_loss: 2.2856 - val_mae: 1.1396
# Epoch 114/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1621 - mae: 1.1030 - val_loss: 2.2810 - val_mae: 1.1009
# Epoch 115/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1397 - mae: 1.1083 - val_loss: 2.1929 - val_mae: 1.0882
# Epoch 116/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1636 - mae: 1.1101 - val_loss: 2.1939 - val_mae: 1.0811
# Epoch 117/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1241 - mae: 1.0970 - val_loss: 2.1938 - val_mae: 1.0940
# Epoch 118/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.1357 - mae: 1.1001 - val_loss: 2.1903 - val_mae: 1.0864
# Epoch 119/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1663 - mae: 1.1034 - val_loss: 2.1962 - val_mae: 1.0916
# Epoch 120/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1572 - mae: 1.1044 - val_loss: 2.2327 - val_mae: 1.0876
# Epoch 121/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1324 - mae: 1.0976 - val_loss: 2.4086 - val_mae: 1.1888
# Epoch 122/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1337 - mae: 1.0999 - val_loss: 2.1984 - val_mae: 1.0801
# Epoch 123/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1144 - mae: 1.0919 - val_loss: 2.2354 - val_mae: 1.0852
# Epoch 124/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1086 - mae: 1.0865 - val_loss: 2.3622 - val_mae: 1.1750
# Epoch 125/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1503 - mae: 1.1008 - val_loss: 2.2478 - val_mae: 1.1286
# Epoch 126/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1136 - mae: 1.0990 - val_loss: 2.1796 - val_mae: 1.0943
# Epoch 127/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1202 - mae: 1.0929 - val_loss: 2.1682 - val_mae: 1.0840
# Epoch 128/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0970 - mae: 1.0807 - val_loss: 2.7286 - val_mae: 1.2831
# Epoch 129/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1169 - mae: 1.0825 - val_loss: 2.1616 - val_mae: 1.0794
# Epoch 130/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0987 - mae: 1.0810 - val_loss: 2.1532 - val_mae: 1.0764
# Epoch 131/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1201 - mae: 1.0942 - val_loss: 2.5038 - val_mae: 1.2222
# Epoch 132/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1289 - mae: 1.0944 - val_loss: 2.4605 - val_mae: 1.2086
# Epoch 133/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1034 - mae: 1.0912 - val_loss: 2.1571 - val_mae: 1.0859
# Epoch 134/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1005 - mae: 1.0922 - val_loss: 2.1457 - val_mae: 1.0748
# Epoch 135/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0763 - mae: 1.0813 - val_loss: 2.1421 - val_mae: 1.0711
# Epoch 136/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0564 - mae: 1.0757 - val_loss: 2.4973 - val_mae: 1.2175
# Epoch 137/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0915 - mae: 1.0973 - val_loss: 2.1493 - val_mae: 1.0789
# Epoch 138/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0507 - mae: 1.0779 - val_loss: 2.1317 - val_mae: 1.0652
# Epoch 139/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1084 - mae: 1.0929 - val_loss: 2.1743 - val_mae: 1.0991
# Epoch 140/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0684 - mae: 1.0834 - val_loss: 2.2184 - val_mae: 1.1172
# Epoch 141/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0569 - mae: 1.0732 - val_loss: 2.1670 - val_mae: 1.0963
# Epoch 142/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0714 - mae: 1.0857 - val_loss: 2.1188 - val_mae: 1.0638
# Epoch 143/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0399 - mae: 1.0813 - val_loss: 2.3572 - val_mae: 1.1233
# Epoch 144/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.1054 - mae: 1.0998 - val_loss: 2.1391 - val_mae: 1.0840
# Epoch 145/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0281 - mae: 1.0717 - val_loss: 2.1473 - val_mae: 1.0604
# Epoch 146/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0643 - mae: 1.0786 - val_loss: 2.1261 - val_mae: 1.0544
# Epoch 147/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0485 - mae: 1.0728 - val_loss: 2.2466 - val_mae: 1.0917
# Epoch 148/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0064 - mae: 1.0636 - val_loss: 2.7119 - val_mae: 1.2772
# Epoch 149/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0534 - mae: 1.0798 - val_loss: 2.1226 - val_mae: 1.0815
# Epoch 150/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0635 - mae: 1.0845 - val_loss: 2.1755 - val_mae: 1.1015
# Epoch 151/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0724 - mae: 1.0866 - val_loss: 2.0892 - val_mae: 1.0660
# Epoch 152/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0485 - mae: 1.0842 - val_loss: 2.3144 - val_mae: 1.1561
# Epoch 153/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0389 - mae: 1.0735 - val_loss: 2.0960 - val_mae: 1.0588
# Epoch 154/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0187 - mae: 1.0622 - val_loss: 2.0999 - val_mae: 1.0726
# Epoch 155/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0238 - mae: 1.0679 - val_loss: 2.1693 - val_mae: 1.0727
# Epoch 156/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0041 - mae: 1.0663 - val_loss: 2.0759 - val_mae: 1.0539
# Epoch 157/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0108 - mae: 1.0725 - val_loss: 2.0838 - val_mae: 1.0683
# Epoch 158/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 2.0159 - mae: 1.0704 - val_loss: 2.0846 - val_mae: 1.0446
# Epoch 159/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0264 - mae: 1.0801 - val_loss: 2.1672 - val_mae: 1.1000
# Epoch 160/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0053 - mae: 1.0592 - val_loss: 2.0744 - val_mae: 1.0602
# Epoch 161/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0013 - mae: 1.0612 - val_loss: 2.0864 - val_mae: 1.0425
# Epoch 162/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 2.0316 - mae: 1.0740 - val_loss: 2.0465 - val_mae: 1.0480
# Epoch 163/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9946 - mae: 1.0684 - val_loss: 2.1333 - val_mae: 1.0863
# Epoch 164/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9881 - mae: 1.0676 - val_loss: 2.1793 - val_mae: 1.1029
# Epoch 165/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9651 - mae: 1.0493 - val_loss: 2.0441 - val_mae: 1.0482
# Epoch 166/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9775 - mae: 1.0647 - val_loss: 2.0280 - val_mae: 1.0296
# Epoch 167/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9687 - mae: 1.0545 - val_loss: 2.0127 - val_mae: 1.0348
# Epoch 168/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.9937 - mae: 1.0617 - val_loss: 2.1291 - val_mae: 1.0836
# Epoch 169/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9777 - mae: 1.0494 - val_loss: 2.0179 - val_mae: 1.0435
# Epoch 170/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9758 - mae: 1.0625 - val_loss: 2.1753 - val_mae: 1.1011
# Epoch 171/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9558 - mae: 1.0529 - val_loss: 2.1085 - val_mae: 1.0756
# Epoch 172/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9856 - mae: 1.0659 - val_loss: 2.1538 - val_mae: 1.0927
# Epoch 173/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9979 - mae: 1.0724 - val_loss: 2.0088 - val_mae: 1.0385
# Epoch 174/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9588 - mae: 1.0612 - val_loss: 2.0303 - val_mae: 1.0461
# Epoch 175/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9456 - mae: 1.0637 - val_loss: 2.0069 - val_mae: 1.0197
# Epoch 176/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9111 - mae: 1.0425 - val_loss: 2.0232 - val_mae: 1.0188
# Epoch 177/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9361 - mae: 1.0542 - val_loss: 1.9970 - val_mae: 1.0139
# Epoch 178/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9261 - mae: 1.0436 - val_loss: 2.4508 - val_mae: 1.1864
# Epoch 179/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9518 - mae: 1.0590 - val_loss: 1.9990 - val_mae: 1.0123
# Epoch 180/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9415 - mae: 1.0597 - val_loss: 1.9613 - val_mae: 1.0172
# Epoch 181/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9035 - mae: 1.0443 - val_loss: 2.0213 - val_mae: 1.0450
# Epoch 182/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8896 - mae: 1.0452 - val_loss: 1.9480 - val_mae: 1.0093
# Epoch 183/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9081 - mae: 1.0415 - val_loss: 1.9924 - val_mae: 1.0351
# Epoch 184/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8963 - mae: 1.0411 - val_loss: 1.9368 - val_mae: 0.9989
# Epoch 185/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9014 - mae: 1.0474 - val_loss: 1.9493 - val_mae: 1.0036
# Epoch 186/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8915 - mae: 1.0380 - val_loss: 1.9216 - val_mae: 0.9939
# Epoch 187/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8934 - mae: 1.0449 - val_loss: 1.9042 - val_mae: 0.9967
# Epoch 188/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.8708 - mae: 1.0458 - val_loss: 1.9012 - val_mae: 0.9909
# Epoch 189/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8858 - mae: 1.0399 - val_loss: 1.8999 - val_mae: 0.9897
# Epoch 190/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8681 - mae: 1.0328 - val_loss: 2.2153 - val_mae: 1.1151
# Epoch 191/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8357 - mae: 1.0169 - val_loss: 1.8925 - val_mae: 0.9845
# Epoch 192/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.9281 - mae: 1.0553 - val_loss: 1.8954 - val_mae: 0.9812
# Epoch 193/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7985 - mae: 1.0027 - val_loss: 1.9208 - val_mae: 0.9829
# Epoch 194/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8613 - mae: 1.0321 - val_loss: 1.9079 - val_mae: 1.0092
# Epoch 195/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8393 - mae: 1.0283 - val_loss: 1.9364 - val_mae: 1.0187
# Epoch 196/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8108 - mae: 1.0178 - val_loss: 1.8794 - val_mae: 0.9993
# Epoch 197/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8091 - mae: 1.0272 - val_loss: 1.8668 - val_mae: 0.9771
# Epoch 198/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8237 - mae: 1.0270 - val_loss: 1.8653 - val_mae: 0.9730
# Epoch 199/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8423 - mae: 1.0178 - val_loss: 1.8260 - val_mae: 0.9773
# Epoch 200/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7807 - mae: 1.0075 - val_loss: 2.0697 - val_mae: 1.0699
# Epoch 201/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8173 - mae: 1.0139 - val_loss: 1.8229 - val_mae: 0.9751
# Epoch 202/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7862 - mae: 1.0150 - val_loss: 1.8212 - val_mae: 0.9758
# Epoch 203/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7590 - mae: 0.9941 - val_loss: 1.8248 - val_mae: 0.9624
# Epoch 204/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.8045 - mae: 1.0187 - val_loss: 1.8219 - val_mae: 0.9636
# Epoch 205/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7916 - mae: 1.0097 - val_loss: 1.8233 - val_mae: 0.9629
# Epoch 206/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7502 - mae: 0.9930 - val_loss: 1.8340 - val_mae: 0.9610
# Epoch 207/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7741 - mae: 1.0103 - val_loss: 1.7850 - val_mae: 0.9577
# Epoch 208/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.7616 - mae: 1.0045 - val_loss: 1.8140 - val_mae: 0.9826
# Epoch 209/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7171 - mae: 0.9924 - val_loss: 1.8294 - val_mae: 0.9636
# Epoch 210/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7370 - mae: 1.0070 - val_loss: 1.7581 - val_mae: 0.9501
# Epoch 211/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7190 - mae: 0.9959 - val_loss: 1.8810 - val_mae: 1.0088
# Epoch 212/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7303 - mae: 0.9935 - val_loss: 1.7957 - val_mae: 0.9479
# Epoch 213/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.7143 - mae: 0.9959 - val_loss: 1.7420 - val_mae: 0.9429
# Epoch 214/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6985 - mae: 0.9883 - val_loss: 1.7253 - val_mae: 0.9505
# Epoch 215/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6835 - mae: 0.9757 - val_loss: 1.8406 - val_mae: 0.9991
# Epoch 216/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6898 - mae: 0.9841 - val_loss: 1.8241 - val_mae: 0.9950
# Epoch 217/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6609 - mae: 0.9780 - val_loss: 1.7701 - val_mae: 0.9745
# Epoch 218/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6624 - mae: 0.9713 - val_loss: 1.7045 - val_mae: 0.9496
# Epoch 219/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6782 - mae: 0.9832 - val_loss: 1.7232 - val_mae: 0.9591
# Epoch 220/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6543 - mae: 0.9752 - val_loss: 1.7208 - val_mae: 0.9623
# Epoch 221/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6344 - mae: 0.9706 - val_loss: 1.9507 - val_mae: 0.9963
# Epoch 222/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6311 - mae: 0.9801 - val_loss: 1.7228 - val_mae: 0.9643
# Epoch 223/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6311 - mae: 0.9757 - val_loss: 1.6826 - val_mae: 0.9305
# Epoch 224/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6547 - mae: 0.9799 - val_loss: 1.6711 - val_mae: 0.9246
# Epoch 225/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6335 - mae: 0.9646 - val_loss: 1.6299 - val_mae: 0.9173
# Epoch 226/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5993 - mae: 0.9628 - val_loss: 1.6155 - val_mae: 0.9263
# Epoch 227/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6366 - mae: 0.9701 - val_loss: 1.6687 - val_mae: 0.9493
# Epoch 228/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5690 - mae: 0.9461 - val_loss: 1.6416 - val_mae: 0.9415
# Epoch 229/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5936 - mae: 0.9610 - val_loss: 1.6056 - val_mae: 0.9285
# Epoch 230/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.5797 - mae: 0.9639 - val_loss: 1.6328 - val_mae: 0.9393
# Epoch 231/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.6098 - mae: 0.9763 - val_loss: 1.5989 - val_mae: 0.9094
# Epoch 232/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5828 - mae: 0.9639 - val_loss: 1.5853 - val_mae: 0.9268
# Epoch 233/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5550 - mae: 0.9524 - val_loss: 1.5862 - val_mae: 0.9093
# Epoch 234/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5533 - mae: 0.9601 - val_loss: 1.6324 - val_mae: 0.9145
# Epoch 235/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5660 - mae: 0.9547 - val_loss: 1.5650 - val_mae: 0.9203
# Epoch 236/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5769 - mae: 0.9687 - val_loss: 1.5789 - val_mae: 0.9037
# Epoch 237/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5603 - mae: 0.9512 - val_loss: 1.6999 - val_mae: 0.9743
# Epoch 238/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4865 - mae: 0.9251 - val_loss: 1.6178 - val_mae: 0.9434
# Epoch 239/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5662 - mae: 0.9551 - val_loss: 1.5319 - val_mae: 0.8981
# Epoch 240/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5490 - mae: 0.9606 - val_loss: 1.5226 - val_mae: 0.9041
# Epoch 241/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5082 - mae: 0.9386 - val_loss: 1.5383 - val_mae: 0.9168
# Epoch 242/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5241 - mae: 0.9427 - val_loss: 1.5521 - val_mae: 0.8951
# Epoch 243/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5120 - mae: 0.9407 - val_loss: 1.5808 - val_mae: 0.9347
# Epoch 244/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5146 - mae: 0.9452 - val_loss: 1.5578 - val_mae: 0.9218
# Epoch 245/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5042 - mae: 0.9438 - val_loss: 1.5235 - val_mae: 0.9094
# Epoch 246/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5297 - mae: 0.9504 - val_loss: 1.4982 - val_mae: 0.8966
# Epoch 247/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4509 - mae: 0.9157 - val_loss: 1.5100 - val_mae: 0.9069
# Epoch 248/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5173 - mae: 0.9529 - val_loss: 1.4903 - val_mae: 0.8858
# Epoch 249/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.5297 - mae: 0.9563 - val_loss: 1.5693 - val_mae: 0.9316
# Epoch 250/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4808 - mae: 0.9323 - val_loss: 1.4681 - val_mae: 0.8933
# Epoch 251/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4808 - mae: 0.9347 - val_loss: 1.4767 - val_mae: 0.8977
# Epoch 252/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4394 - mae: 0.9213 - val_loss: 1.7582 - val_mae: 1.0025
# Epoch 253/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4577 - mae: 0.9325 - val_loss: 1.4929 - val_mae: 0.9052
# Epoch 254/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4620 - mae: 0.9315 - val_loss: 1.4548 - val_mae: 0.8920
# Epoch 255/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4348 - mae: 0.9210 - val_loss: 1.5281 - val_mae: 0.8852
# Epoch 256/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4506 - mae: 0.9248 - val_loss: 1.4440 - val_mae: 0.8895
# Epoch 257/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4676 - mae: 0.9308 - val_loss: 1.4852 - val_mae: 0.9063
# Epoch 258/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4483 - mae: 0.9282 - val_loss: 1.4376 - val_mae: 0.8887
# Epoch 259/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4413 - mae: 0.9218 - val_loss: 1.5210 - val_mae: 0.9217
# Epoch 260/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4468 - mae: 0.9304 - val_loss: 1.4238 - val_mae: 0.8666
# Epoch 261/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4221 - mae: 0.9184 - val_loss: 1.4609 - val_mae: 0.8978
# Epoch 262/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4432 - mae: 0.9246 - val_loss: 1.5242 - val_mae: 0.9272
# Epoch 263/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4465 - mae: 0.9282 - val_loss: 1.4075 - val_mae: 0.8748
# Epoch 264/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4235 - mae: 0.9334 - val_loss: 1.4455 - val_mae: 0.8957
# Epoch 265/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3865 - mae: 0.9128 - val_loss: 1.4329 - val_mae: 0.8966
# Epoch 266/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4040 - mae: 0.9209 - val_loss: 1.6165 - val_mae: 0.9178
# Epoch 267/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4394 - mae: 0.9301 - val_loss: 1.4033 - val_mae: 0.8818
# Epoch 268/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4220 - mae: 0.9257 - val_loss: 1.3983 - val_mae: 0.8623
# Epoch 269/1000
# 30/30 [==============================] - 0s 8ms/step - loss: 1.4099 - mae: 0.9194 - val_loss: 1.4012 - val_mae: 0.8860
# Epoch 270/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3966 - mae: 0.9268 - val_loss: 1.4512 - val_mae: 0.9019
# Epoch 271/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.3834 - mae: 0.9049 - val_loss: 1.3639 - val_mae: 0.8610
# Epoch 272/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4301 - mae: 0.9252 - val_loss: 1.3953 - val_mae: 0.8823
# Epoch 273/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3770 - mae: 0.9117 - val_loss: 1.6579 - val_mae: 0.9794
# Epoch 274/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4314 - mae: 0.9284 - val_loss: 1.3595 - val_mae: 0.8620
# Epoch 275/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3471 - mae: 0.9079 - val_loss: 1.4395 - val_mae: 0.9016
# Epoch 276/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3599 - mae: 0.9035 - val_loss: 1.4529 - val_mae: 0.8694
# Epoch 277/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3984 - mae: 0.9334 - val_loss: 1.3709 - val_mae: 0.8572
# Epoch 278/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3904 - mae: 0.9124 - val_loss: 1.3979 - val_mae: 0.8605
# Epoch 279/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3798 - mae: 0.9124 - val_loss: 1.3897 - val_mae: 0.8601
# Epoch 280/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3909 - mae: 0.9221 - val_loss: 1.3334 - val_mae: 0.8630
# Epoch 281/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.4187 - mae: 0.9361 - val_loss: 1.3430 - val_mae: 0.8708
# Epoch 282/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3295 - mae: 0.9009 - val_loss: 1.3440 - val_mae: 0.8721
# Epoch 283/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3138 - mae: 0.8907 - val_loss: 1.4819 - val_mae: 0.9243
# Epoch 284/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3765 - mae: 0.9112 - val_loss: 1.3541 - val_mae: 0.8540
# Epoch 285/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3431 - mae: 0.8992 - val_loss: 1.3254 - val_mae: 0.8631
# Epoch 286/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3922 - mae: 0.9218 - val_loss: 1.3721 - val_mae: 0.8623
# Epoch 287/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.3710 - mae: 0.9141 - val_loss: 1.3512 - val_mae: 0.8538
# Epoch 288/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3303 - mae: 0.9074 - val_loss: 1.3062 - val_mae: 0.8600
# Epoch 289/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3282 - mae: 0.8899 - val_loss: 1.4484 - val_mae: 0.9172
# Epoch 290/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3600 - mae: 0.9221 - val_loss: 1.3258 - val_mae: 0.8684
# Epoch 291/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3346 - mae: 0.9079 - val_loss: 1.3216 - val_mae: 0.8513
# Epoch 292/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3111 - mae: 0.8915 - val_loss: 1.4767 - val_mae: 0.9284
# Epoch 293/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3258 - mae: 0.9015 - val_loss: 1.4837 - val_mae: 0.9306
# Epoch 294/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3325 - mae: 0.9063 - val_loss: 1.3543 - val_mae: 0.8817
# Epoch 295/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3101 - mae: 0.8896 - val_loss: 1.3002 - val_mae: 0.8512
# Epoch 296/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3957 - mae: 0.9269 - val_loss: 1.3075 - val_mae: 0.8661
# Epoch 297/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3214 - mae: 0.9074 - val_loss: 1.3105 - val_mae: 0.8464
# Epoch 298/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3121 - mae: 0.8863 - val_loss: 1.2853 - val_mae: 0.8619
# Epoch 299/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3380 - mae: 0.9086 - val_loss: 1.2781 - val_mae: 0.8445
# Epoch 300/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2857 - mae: 0.8919 - val_loss: 1.2964 - val_mae: 0.8612
# Epoch 301/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2955 - mae: 0.8958 - val_loss: 1.2763 - val_mae: 0.8565
# Epoch 302/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2992 - mae: 0.9055 - val_loss: 1.4475 - val_mae: 0.8729
# Epoch 303/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3138 - mae: 0.8952 - val_loss: 1.2698 - val_mae: 0.8547
# Epoch 304/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.3054 - mae: 0.8937 - val_loss: 1.2567 - val_mae: 0.8413
# Epoch 305/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2979 - mae: 0.8914 - val_loss: 1.2964 - val_mae: 0.8675
# Epoch 306/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2896 - mae: 0.8966 - val_loss: 1.2929 - val_mae: 0.8668
# Epoch 307/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2726 - mae: 0.8965 - val_loss: 1.3600 - val_mae: 0.8958
# Epoch 308/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3033 - mae: 0.9015 - val_loss: 1.2557 - val_mae: 0.8433
# Epoch 309/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2811 - mae: 0.8885 - val_loss: 1.2452 - val_mae: 0.8461
# Epoch 310/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3403 - mae: 0.9141 - val_loss: 1.2604 - val_mae: 0.8584
# Epoch 311/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2975 - mae: 0.9025 - val_loss: 1.2402 - val_mae: 0.8476
# Epoch 312/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2895 - mae: 0.8913 - val_loss: 1.2456 - val_mae: 0.8527
# Epoch 313/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2899 - mae: 0.8885 - val_loss: 1.3284 - val_mae: 0.8482
# Epoch 314/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2693 - mae: 0.8962 - val_loss: 1.2409 - val_mae: 0.8441
# Epoch 315/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2957 - mae: 0.8916 - val_loss: 1.2319 - val_mae: 0.8403
# Epoch 316/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3493 - mae: 0.9149 - val_loss: 1.2349 - val_mae: 0.8432
# Epoch 317/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2439 - mae: 0.8867 - val_loss: 1.2978 - val_mae: 0.8444
# Epoch 318/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2634 - mae: 0.8932 - val_loss: 1.3526 - val_mae: 0.8507
# Epoch 319/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2872 - mae: 0.8870 - val_loss: 1.3383 - val_mae: 0.8854
# Epoch 320/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2855 - mae: 0.8914 - val_loss: 1.2951 - val_mae: 0.8380
# Epoch 321/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2659 - mae: 0.8900 - val_loss: 1.2819 - val_mae: 0.8353
# Epoch 322/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2544 - mae: 0.8740 - val_loss: 1.2466 - val_mae: 0.8531
# Epoch 323/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2249 - mae: 0.8634 - val_loss: 1.2173 - val_mae: 0.8361
# Epoch 324/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2547 - mae: 0.8805 - val_loss: 1.2123 - val_mae: 0.8350
# Epoch 325/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2943 - mae: 0.8899 - val_loss: 1.2233 - val_mae: 0.8491
# Epoch 326/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3061 - mae: 0.9002 - val_loss: 1.2919 - val_mae: 0.8739
# Epoch 327/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2792 - mae: 0.8926 - val_loss: 1.2261 - val_mae: 0.8518
# Epoch 328/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2772 - mae: 0.8836 - val_loss: 1.2343 - val_mae: 0.8536
# Epoch 329/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2288 - mae: 0.8739 - val_loss: 1.2437 - val_mae: 0.8579
# Epoch 330/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1985 - mae: 0.8655 - val_loss: 1.2506 - val_mae: 0.8287
# Epoch 331/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2306 - mae: 0.8738 - val_loss: 1.4047 - val_mae: 0.8673
# Epoch 332/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2490 - mae: 0.8771 - val_loss: 1.1967 - val_mae: 0.8299
# Epoch 333/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.3117 - mae: 0.8934 - val_loss: 1.1864 - val_mae: 0.8304
# Epoch 334/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2177 - mae: 0.8752 - val_loss: 1.2569 - val_mae: 0.8300
# Epoch 335/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2224 - mae: 0.8734 - val_loss: 1.1994 - val_mae: 0.8442
# Epoch 336/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2107 - mae: 0.8604 - val_loss: 1.4313 - val_mae: 0.8821
# Epoch 337/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2302 - mae: 0.8810 - val_loss: 1.2093 - val_mae: 0.8192
# Epoch 338/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2553 - mae: 0.8726 - val_loss: 1.3361 - val_mae: 0.8964
# Epoch 339/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2246 - mae: 0.8727 - val_loss: 1.1730 - val_mae: 0.8264
# Epoch 340/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1935 - mae: 0.8612 - val_loss: 1.1857 - val_mae: 0.8252
# Epoch 341/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2600 - mae: 0.8755 - val_loss: 1.1894 - val_mae: 0.8403
# Epoch 342/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1844 - mae: 0.8578 - val_loss: 1.1974 - val_mae: 0.8259
# Epoch 343/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2721 - mae: 0.8866 - val_loss: 1.2005 - val_mae: 0.8245
# Epoch 344/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2214 - mae: 0.8672 - val_loss: 1.2922 - val_mae: 0.8798
# Epoch 345/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2281 - mae: 0.8787 - val_loss: 1.1723 - val_mae: 0.8289
# Epoch 346/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2334 - mae: 0.8695 - val_loss: 1.1959 - val_mae: 0.8208
# Epoch 347/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2073 - mae: 0.8747 - val_loss: 1.2122 - val_mae: 0.8232
# Epoch 348/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2149 - mae: 0.8700 - val_loss: 1.1677 - val_mae: 0.8292
# Epoch 349/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2316 - mae: 0.8688 - val_loss: 1.2476 - val_mae: 0.8307
# Epoch 350/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2130 - mae: 0.8703 - val_loss: 1.2774 - val_mae: 0.8787
# Epoch 351/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2209 - mae: 0.8707 - val_loss: 1.2824 - val_mae: 0.8776
# Epoch 352/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2420 - mae: 0.8812 - val_loss: 1.1691 - val_mae: 0.8209
# Epoch 353/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1739 - mae: 0.8620 - val_loss: 1.2838 - val_mae: 0.8807
# Epoch 354/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1952 - mae: 0.8721 - val_loss: 1.1590 - val_mae: 0.8260
# Epoch 355/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2034 - mae: 0.8659 - val_loss: 1.1829 - val_mae: 0.8188
# Epoch 356/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1708 - mae: 0.8567 - val_loss: 1.1650 - val_mae: 0.8174
# Epoch 357/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.2273 - mae: 0.8748 - val_loss: 1.2131 - val_mae: 0.8502
# Epoch 358/1000
# ...
# Epoch 882/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0610 - mae: 0.8129 - val_loss: 0.9572 - val_mae: 0.7680
# Epoch 883/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0498 - mae: 0.8166 - val_loss: 0.9470 - val_mae: 0.7857
# Epoch 884/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0560 - mae: 0.8162 - val_loss: 0.9601 - val_mae: 0.7918
# Epoch 885/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0722 - mae: 0.8240 - val_loss: 0.9496 - val_mae: 0.7734
# Epoch 886/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0745 - mae: 0.8304 - val_loss: 0.9841 - val_mae: 0.7717
# Epoch 887/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0605 - mae: 0.8330 - val_loss: 1.0982 - val_mae: 0.7953
# Epoch 888/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0558 - mae: 0.8258 - val_loss: 0.9993 - val_mae: 0.8081
# Epoch 889/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0466 - mae: 0.8195 - val_loss: 0.9459 - val_mae: 0.7829
# Epoch 890/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0552 - mae: 0.8160 - val_loss: 0.9391 - val_mae: 0.7779
# Epoch 891/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1290 - mae: 0.8469 - val_loss: 0.9518 - val_mae: 0.7620
# Epoch 892/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0398 - mae: 0.8170 - val_loss: 1.0466 - val_mae: 0.7802
# Epoch 893/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0610 - mae: 0.8246 - val_loss: 1.1504 - val_mae: 0.8633
# Epoch 894/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0378 - mae: 0.8126 - val_loss: 0.9694 - val_mae: 0.7659
# Epoch 895/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0929 - mae: 0.8369 - val_loss: 0.9472 - val_mae: 0.7682
# Epoch 896/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0096 - mae: 0.8028 - val_loss: 1.0729 - val_mae: 0.8372
# Epoch 897/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0404 - mae: 0.8112 - val_loss: 0.9605 - val_mae: 0.7945
# Epoch 898/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0348 - mae: 0.8177 - val_loss: 0.9850 - val_mae: 0.7758
# Epoch 899/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0443 - mae: 0.8176 - val_loss: 1.1025 - val_mae: 0.8486
# Epoch 900/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0896 - mae: 0.8361 - val_loss: 0.9802 - val_mae: 0.7710
# Epoch 901/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0383 - mae: 0.8182 - val_loss: 0.9328 - val_mae: 0.7771
# Epoch 902/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0513 - mae: 0.8186 - val_loss: 1.0358 - val_mae: 0.7818
# Epoch 903/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0598 - mae: 0.8243 - val_loss: 0.9904 - val_mae: 0.7653
# Epoch 904/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0901 - mae: 0.8291 - val_loss: 1.0877 - val_mae: 0.8427
# Epoch 905/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0759 - mae: 0.8308 - val_loss: 0.9803 - val_mae: 0.7666
# Epoch 906/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1028 - mae: 0.8383 - val_loss: 0.9614 - val_mae: 0.7946
# Epoch 907/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0133 - mae: 0.8073 - val_loss: 0.9833 - val_mae: 0.8030
# Epoch 908/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0918 - mae: 0.8331 - val_loss: 1.1623 - val_mae: 0.8679
# Epoch 909/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0946 - mae: 0.8321 - val_loss: 0.9788 - val_mae: 0.7996
# Epoch 910/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0295 - mae: 0.8105 - val_loss: 0.9715 - val_mae: 0.7699
# Epoch 911/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0678 - mae: 0.8204 - val_loss: 0.9369 - val_mae: 0.7704
# Epoch 912/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0875 - mae: 0.8336 - val_loss: 0.9375 - val_mae: 0.7765
# Epoch 913/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0844 - mae: 0.8299 - val_loss: 0.9797 - val_mae: 0.8017
# Epoch 914/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0523 - mae: 0.8233 - val_loss: 0.9427 - val_mae: 0.7822
# Epoch 915/1000
# 30/30 [==============================] - 0s 8ms/step - loss: 1.0678 - mae: 0.8283 - val_loss: 0.9454 - val_mae: 0.7854
# Epoch 916/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0511 - mae: 0.8203 - val_loss: 1.0119 - val_mae: 0.7697
# Epoch 917/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1039 - mae: 0.8375 - val_loss: 1.0774 - val_mae: 0.8382
# Epoch 918/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1090 - mae: 0.8401 - val_loss: 0.9383 - val_mae: 0.7710
# Epoch 919/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0137 - mae: 0.8063 - val_loss: 0.9388 - val_mae: 0.7816
# Epoch 920/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0912 - mae: 0.8346 - val_loss: 1.0472 - val_mae: 0.7819
# Epoch 921/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0603 - mae: 0.8219 - val_loss: 1.2467 - val_mae: 0.8931
# Epoch 922/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0889 - mae: 0.8287 - val_loss: 1.0253 - val_mae: 0.8182
# Epoch 923/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0363 - mae: 0.8131 - val_loss: 0.9552 - val_mae: 0.7819
# Epoch 924/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0920 - mae: 0.8351 - val_loss: 1.0016 - val_mae: 0.8104
# Epoch 925/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0836 - mae: 0.8389 - val_loss: 1.0757 - val_mae: 0.8385
# Epoch 926/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0632 - mae: 0.8147 - val_loss: 0.9382 - val_mae: 0.7793
# Epoch 927/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0838 - mae: 0.8303 - val_loss: 0.9555 - val_mae: 0.7661
# Epoch 928/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0699 - mae: 0.8280 - val_loss: 1.1741 - val_mae: 0.8698
# Epoch 929/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0620 - mae: 0.8368 - val_loss: 1.0936 - val_mae: 0.8452
# Epoch 930/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0739 - mae: 0.8395 - val_loss: 0.9800 - val_mae: 0.7713
# Epoch 931/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0972 - mae: 0.8354 - val_loss: 0.9568 - val_mae: 0.7909
# Epoch 932/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1024 - mae: 0.8356 - val_loss: 0.9550 - val_mae: 0.7755
# Epoch 933/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0510 - mae: 0.8124 - val_loss: 0.9523 - val_mae: 0.7905
# Epoch 934/1000
# 30/30 [==============================] - 0s 3ms/step - loss: 1.0190 - mae: 0.8120 - val_loss: 0.9549 - val_mae: 0.7913
# Epoch 935/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0864 - mae: 0.8226 - val_loss: 0.9665 - val_mae: 0.7946
# Epoch 936/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0890 - mae: 0.8372 - val_loss: 1.0913 - val_mae: 0.8437
# Epoch 937/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0953 - mae: 0.8310 - val_loss: 0.9425 - val_mae: 0.7846
# Epoch 938/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0824 - mae: 0.8318 - val_loss: 0.9716 - val_mae: 0.7983
# Epoch 939/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0678 - mae: 0.8293 - val_loss: 0.9533 - val_mae: 0.7906
# Epoch 940/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0389 - mae: 0.8162 - val_loss: 0.9952 - val_mae: 0.7722
# Epoch 941/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0757 - mae: 0.8226 - val_loss: 0.9557 - val_mae: 0.7711
# Epoch 942/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0741 - mae: 0.8246 - val_loss: 1.0926 - val_mae: 0.8452
# Epoch 943/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0396 - mae: 0.8154 - val_loss: 1.3388 - val_mae: 0.9199
# Epoch 944/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1106 - mae: 0.8337 - val_loss: 0.9458 - val_mae: 0.7733
# Epoch 945/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0573 - mae: 0.8212 - val_loss: 0.9461 - val_mae: 0.7706
# Epoch 946/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0931 - mae: 0.8386 - val_loss: 0.9499 - val_mae: 0.7888
# Epoch 947/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1205 - mae: 0.8448 - val_loss: 1.0436 - val_mae: 0.8271
# Epoch 948/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0709 - mae: 0.8250 - val_loss: 0.9701 - val_mae: 0.7983
# Epoch 949/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0404 - mae: 0.8085 - val_loss: 1.0299 - val_mae: 0.8204
# Epoch 950/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0579 - mae: 0.8226 - val_loss: 1.2926 - val_mae: 0.9084
# Epoch 951/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0571 - mae: 0.8134 - val_loss: 0.9464 - val_mae: 0.7870
# Epoch 952/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0631 - mae: 0.8275 - val_loss: 0.9620 - val_mae: 0.7678
# Epoch 953/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0480 - mae: 0.8152 - val_loss: 0.9613 - val_mae: 0.7943
# Epoch 954/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0893 - mae: 0.8325 - val_loss: 0.9371 - val_mae: 0.7761
# Epoch 955/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0740 - mae: 0.8237 - val_loss: 0.9470 - val_mae: 0.7685
# Epoch 956/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0684 - mae: 0.8269 - val_loss: 0.9520 - val_mae: 0.7897
# Epoch 957/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0746 - mae: 0.8394 - val_loss: 1.1386 - val_mae: 0.8594
# Epoch 958/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0796 - mae: 0.8324 - val_loss: 0.9678 - val_mae: 0.7970
# Epoch 959/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0425 - mae: 0.8186 - val_loss: 0.9680 - val_mae: 0.7948
# Epoch 960/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0807 - mae: 0.8134 - val_loss: 0.9330 - val_mae: 0.7776
# Epoch 961/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0704 - mae: 0.8345 - val_loss: 0.9515 - val_mae: 0.7889
# Epoch 962/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0740 - mae: 0.8270 - val_loss: 0.9410 - val_mae: 0.7800
# Epoch 963/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0770 - mae: 0.8285 - val_loss: 1.5220 - val_mae: 0.9774
# Epoch 964/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1077 - mae: 0.8409 - val_loss: 0.9368 - val_mae: 0.7732
# Epoch 965/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0385 - mae: 0.8116 - val_loss: 0.9510 - val_mae: 0.7894
# Epoch 966/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0446 - mae: 0.8187 - val_loss: 1.0088 - val_mae: 0.7717
# Epoch 967/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0366 - mae: 0.8191 - val_loss: 1.0157 - val_mae: 0.7703
# Epoch 968/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0766 - mae: 0.8307 - val_loss: 0.9396 - val_mae: 0.7824
# Epoch 969/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0612 - mae: 0.8288 - val_loss: 0.9561 - val_mae: 0.7695
# Epoch 970/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1088 - mae: 0.8310 - val_loss: 1.0027 - val_mae: 0.7730
# Epoch 971/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0143 - mae: 0.8124 - val_loss: 0.9368 - val_mae: 0.7668
# Epoch 972/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1067 - mae: 0.8432 - val_loss: 0.9366 - val_mae: 0.7744
# Epoch 973/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0971 - mae: 0.8372 - val_loss: 0.9821 - val_mae: 0.8037
# Epoch 974/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0479 - mae: 0.8192 - val_loss: 0.9789 - val_mae: 0.7740
# Epoch 975/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1044 - mae: 0.8512 - val_loss: 0.9580 - val_mae: 0.7937
# Epoch 976/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0471 - mae: 0.8181 - val_loss: 0.9636 - val_mae: 0.7934
# Epoch 977/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0471 - mae: 0.8166 - val_loss: 1.3910 - val_mae: 0.9378
# Epoch 978/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1130 - mae: 0.8501 - val_loss: 0.9306 - val_mae: 0.7704
# Epoch 979/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1026 - mae: 0.8377 - val_loss: 1.0913 - val_mae: 0.8444
# Epoch 980/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0396 - mae: 0.8187 - val_loss: 0.9379 - val_mae: 0.7820
# Epoch 981/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1075 - mae: 0.8321 - val_loss: 0.9937 - val_mae: 0.8058
# Epoch 982/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0540 - mae: 0.8171 - val_loss: 0.9462 - val_mae: 0.7851
# Epoch 983/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0842 - mae: 0.8316 - val_loss: 0.9734 - val_mae: 0.7696
# Epoch 984/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0828 - mae: 0.8343 - val_loss: 0.9462 - val_mae: 0.7727
# Epoch 985/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0523 - mae: 0.8180 - val_loss: 1.5414 - val_mae: 0.9858
# Epoch 986/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0846 - mae: 0.8270 - val_loss: 0.9573 - val_mae: 0.7921
# Epoch 987/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0539 - mae: 0.8138 - val_loss: 0.9553 - val_mae: 0.7862
# Epoch 988/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0547 - mae: 0.8145 - val_loss: 1.0172 - val_mae: 0.8159
# Epoch 989/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0939 - mae: 0.8387 - val_loss: 1.0622 - val_mae: 0.8333
# Epoch 990/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0370 - mae: 0.8070 - val_loss: 1.0905 - val_mae: 0.8436
# Epoch 991/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0167 - mae: 0.8060 - val_loss: 1.0799 - val_mae: 0.7917
# Epoch 992/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.1031 - mae: 0.8412 - val_loss: 0.9903 - val_mae: 0.7733
# Epoch 993/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0268 - mae: 0.8230 - val_loss: 1.0190 - val_mae: 0.7749
# Epoch 994/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0673 - mae: 0.8307 - val_loss: 0.9297 - val_mae: 0.7703
# Epoch 995/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0554 - mae: 0.8370 - val_loss: 1.0355 - val_mae: 0.8225
# Epoch 996/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0513 - mae: 0.8168 - val_loss: 0.9495 - val_mae: 0.7874
# Epoch 997/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0222 - mae: 0.8148 - val_loss: 0.9452 - val_mae: 0.7761
# Epoch 998/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0680 - mae: 0.8230 - val_loss: 1.0571 - val_mae: 0.8294
# Epoch 999/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0333 - mae: 0.8136 - val_loss: 0.9457 - val_mae: 0.7662
# Epoch 1000/1000
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0375 - mae: 0.8123 - val_loss: 1.0018 - val_mae: 0.8096
# Done!

# %% [markdown]
# ## Convert the Tensorflow Model to Tensorflow Lite Model

# %%
# Convert the model to the TensorFlow Lite format with quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)
# Out:
# 2552

# %% [markdown]
# ## Predict

# %% [markdown]
# ### Predict with Tensorflow Model

# %%
# Use the model to make predictions from our test data

############################################################
#@markdown How to use the model to predict the result with the test data (`x_test`) and save the result in a variable `predictions`?
script = "predictions = model.predict(x_test)" #@param {type:"string"}
exec(script)
############################################################

# %% [markdown]
# ### Predict with Tensorflow Lite Model

# %%
# Use the Tensorflow lite model to make interfences from our test data
#@markdown Please choose and fill in correct code statements from one of the following:
#@markdown 1. interpreter.invoke() 
#@markdown 2. interpreter_input().fill(x_test[i])
#@markdown 3. interpreter = tf.lite.Interpreter('model.tflite')
#@markdown 4. interpreter_predictions[i] = interpreter_output()[0]
#@markdown 5. interpreter_output = interpreter.tensor(interpreter.get_output_details()[0]["index"])
#@markdown 6. interpreter_input = interpreter.tensor(interpreter.get_input_details()[0]["index"])

############################################################
# Instantiate an interpreter for the TFLite model
#@markdown Which is the statement to instantiate an interpreter with a TFLite Model named `model.tflite`?
script_1 = "interpreter = tf.lite.Interpreter('model.tflite')" #@param {type:"string"}
exec(script_1)
############################################################

# Allocate memory for the model
interpreter.allocate_tensors()

############################################################
# Get the input tensors so we can feed in values 
#@markdown Which is the statement to get input sensors?
script_2 = "interpreter_input = interpreter.tensor(interpreter.get_input_details()[0][\"index\"])" #@param {type:"string"}
exec(script_2)
############################################################

############################################################
# Get the output tensors so we can get the results
#@markdown Which is the statement to get output sensors?
script_3 = "interpreter_output = interpreter.tensor(interpreter.get_output_details()[0][\"index\"])" #@param {type:"string"}
exec(script_3)
############################################################

# Create arrays to store the results
interpreter_predictions = np.empty(x_test.size)

# Run each model's interpreter for each value and store the results in arrays
for i in range(x_test.size):
  ############################################################
  #@markdown Which is the statement to fill the input of the interpreter with `x_test[i]`?
  script_4 = "interpreter_input().fill(x_test[i])" #@param {type:"string"}
  exec(script_4)
  ############################################################
  ############################################################
  #@markdown Which is the statement to invoke the interpreter?
  script_5 = "interpreter.invoke()" #@param {type:"string"}
  exec(script_5)
  ############################################################
  ############################################################
  #@markdown Which is the statement to get the output from the interpreter and save the output in `interpreter_predictions[i]`?
  script_6 = "interpreter_predictions[i] = interpreter_output()[0]"#@param {type:"string"}
  exec(script_6)
  ############################################################


# Make the shape of the y_test be the same as the predictions
y_test = np.reshape(y_test, predictions.shape)
# Make the shape of the interpreter_predictions be the same as the predictions
interpreter_predictions = np.reshape(interpreter_predictions, predictions.shape)

# %% [markdown]
# ## Plot the Result

# %%
plt.clf()
plt.title('Test data predicted vs actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted (tensorflow)')
############################################################
#@markdown Please write the statement to plot the outputs in green dots with a label `Predicted (tflite)` from the interpreter.
script = "plt.plot(x_test, interpreter_predictions, 'g.', label='Predicted (tflite)')"#@param {type:"string"}
exec(script)
############################################################
plt.legend()
plt.show()
